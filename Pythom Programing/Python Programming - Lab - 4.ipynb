# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 4</b></center>
# <pre>

# %% [markdown]
# # String

# %% [markdown]
# ### 01) WAP to check whether the given string is palindrome or not.

# %%
s=input('Enter String')

if s==s[::-1]:
    print('String Palindrome')
else:
    print('String not Palindrome')
# Out:
# Enter String abc
# String not Palindrome

# %% [markdown]
# ### 02) WAP to reverse the words in the given string.

# %%
s=input('Enter String')

print(s[::-1])
# Out:
# Enter String hamrik
# kirmah

# %% [markdown]
# ### 03) WAP to remove ith character from given string.

# %%
string=input('Enter String')
index=int(input('Enter remove character index'))

finalString=string[:index]+string[index+1:]

print(finalString)
# Out:
# Enter String harmik
# Enter remove character index 1
# hrmik

# %% [markdown]
# ### 04) WAP to find length of string without using len function.

# %%
string=input('Enter String')

count=0
for i in string:
    count+=1

print(f'length of string is {count}')
# Out:
# Enter String harmik
# length of string is 6

# %% [markdown]
# ### 05) WAP to print even length word in string.

# %%
string=input('Enter string')

word=string.split()

for w in word:
    if len(w) % 2 == 0:
        print(w)
# Out:
# Enter a sentence:  ahe
# Even length words:

# %% [markdown]
# ### 06) WAP to count numbers of vowels in given string.

# %%
string=input('Enter String')

string=string.lower()

count=0
for ch in string:
    if ch in 'aeiou':
        count+=1

print(count)
# Out:
# Enter String hArmik
# 2

# %% [markdown]
# ### 07) WAP to capitalize the first and last character of each word in a string.

# %%
string=input('Enter string')

words=string.split()

result=""

for word in words:
    if len(word)==1:
        result+=word.upper()+' '
    else:
        first=word[0].upper()
        last=word[-1].upper()
        middle=word[1:-1]
        result=first+middle+last+' '

print('Output:',result)
# Out:
# Enter string harmik rab
# Output: RaB

# %% [markdown]
# ### 08) WAP to convert given array to string.

# %%
list=['H','a','r','m','i','k']

string=''.join(list)

print(string)
# Out:
# Harmik

# %% [markdown]
# ### 09) Check if the password and confirm password is same or not.
# ### In case of only case's mistake, show the error message.

# %%
password=input('Enter Password')
confirmPassword=input('Enter Confirm Password')

if password==confirmPassword:
    print('Successful')

else:
    print('Both password is not same')
# Out:
# Enter Password harmik
# Enter Confirm Password Harmik
# Both password is not same

# %% [markdown]
# ### 10) : Display credit card number.
# ### card no. : 1234 5678 9012 3456
# ### display as  : **** **** **** 3456

# %%
card="1234 5678 9012 3456"

parts=card.split()

mark=['****' for _ in parts[:-1]]
mark.append(parts[-1])

mark_card=' '.join(mark)

print('Display as: ',mark_card)
# Out:
# Display as:  **** **** **** 3456

# %% [markdown]
# ### 11) : Checking if the two strings are Anagram or not.
# ### s1 = decimal and s2 = medical are Anagram

# %%
s1=input('Enter first string')
s2=input('Enter second string')

s1=s1.replace(' ', '').lower()
s2=s2.replace(' ', '').lower()

if sorted(s1) == sorted(s2):
    print(f'{s1} and {s2} is anagram')
else:
    print(f'{s1} and {s2} is not anagram')
# Out:
# Enter first string harmik
# Enter second string dhruv
# harmik and dhruv is not anagram

# %% [markdown]
# ### 12) : Rearrange the given string. First lowercase then uppercase alphabets.
# ### input : EHlsarwiwhtwMV
# ### output : lsarwiwhtwEHMV

# %%
string=input('Enter mixed string')

lowercase = ''.join(char for char in string if char.islower())
uppercase = ''.join(char for char in string if char.isupper())

output_string=lowercase+uppercase

print(f'Output String {output_string}')
# Out:
# Enter mixed string AkhdiusowSIYWidj
# Output String khdiusowidjASIYW
